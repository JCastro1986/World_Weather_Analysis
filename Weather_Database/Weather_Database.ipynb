# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          #"Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | tuy hoa
# Processing Record 3 of Set 1 | pemangkat
# Processing Record 4 of Set 1 | skibbereen
# Processing Record 5 of Set 1 | grahamstown
# Processing Record 6 of Set 1 | flinders
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | padang
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | kalemie
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | state college
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | menongue
# Processing Record 30 of Set 1 | hamilton
# Processing Record 31 of Set 1 | faya
# Processing Record 32 of Set 1 | mme
# City not found. Skipping...
# Processing Record 33 of Set 1 | baley
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | suluq
# Processing Record 38 of Set 1 | ahipara
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | nguruka
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | yaan
# Processing Record 43 of Set 1 | nicoya
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | merauke
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | winslow
# Processing Record 50 of Set 1 | iroquois falls
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | alyangula
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | kyrksaeterora
# Processing Record 6 of Set 2 | ilka
# City not found. Skipping...
# Processing Record 7 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 2 | port blair
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | raahe
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 2 | ust-maya
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | hasaki
# Processing Record 17 of Set 2 | alepe
# Processing Record 18 of Set 2 | port-gentil
# Processing Record 19 of Set 2 | pacific grove
# Processing Record 20 of Set 2 | sittingbourne
# Processing Record 21 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | alexandria
# Processing Record 24 of Set 2 | khomeyn
# Processing Record 25 of Set 2 | hatsukaichi
# Processing Record 26 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 2 | ambon
# Processing Record 28 of Set 2 | byron bay
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | gazanjyk
# Processing Record 32 of Set 2 | buta
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | peniche
# Processing Record 36 of Set 2 | te anau
# Processing Record 37 of Set 2 | mweka
# Processing Record 38 of Set 2 | tsaratanana
# Processing Record 39 of Set 2 | suez
# Processing Record 40 of Set 2 | taksimo
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | guadalupe victoria
# Processing Record 48 of Set 2 | safford
# Processing Record 49 of Set 2 | margate
# Processing Record 50 of Set 2 | los llanos de aridane
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | pozo colorado
# Processing Record 5 of Set 3 | victoria
# Processing Record 6 of Set 3 | salem
# Processing Record 7 of Set 3 | freeport
# Processing Record 8 of Set 3 | koslan
# Processing Record 9 of Set 3 | lasa
# Processing Record 10 of Set 3 | shimoda
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | wembley
# Processing Record 13 of Set 3 | itaituba
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | chernyshevskiy
# Processing Record 16 of Set 3 | kroya
# Processing Record 17 of Set 3 | garchitorena
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | abalak
# Processing Record 20 of Set 3 | chokurdakh
# Processing Record 21 of Set 3 | veshenskaya
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | kasongo
# Processing Record 24 of Set 3 | marica
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | nome
# Processing Record 27 of Set 3 | nyazepetrovsk
# Processing Record 28 of Set 3 | tyukhtet
# Processing Record 29 of Set 3 | ayan
# Processing Record 30 of Set 3 | manadhoo
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | leningradskiy
# Processing Record 33 of Set 3 | carnoustie
# Processing Record 34 of Set 3 | sinnamary
# Processing Record 35 of Set 3 | sao jose da coroa grande
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | xanlar
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | piacabucu
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | aquiraz
# Processing Record 43 of Set 3 | naisud
# Processing Record 44 of Set 3 | chara
# Processing Record 45 of Set 3 | progreso
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | tongliao
# Processing Record 48 of Set 3 | nkawkaw
# Processing Record 49 of Set 3 | lakes entrance
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | manali
# Processing Record 2 of Set 4 | juegang
# Processing Record 3 of Set 4 | palencia
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | norman wells
# Processing Record 7 of Set 4 | lake cowichan
# Processing Record 8 of Set 4 | blackwater
# Processing Record 9 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | souillac
# Processing Record 13 of Set 4 | north bend
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | pisco
# Processing Record 17 of Set 4 | paamiut
# Processing Record 18 of Set 4 | kirakira
# Processing Record 19 of Set 4 | horni plana
# Processing Record 20 of Set 4 | lodja
# Processing Record 21 of Set 4 | ercis
# Processing Record 22 of Set 4 | maraa
# Processing Record 23 of Set 4 | nichinan
# Processing Record 24 of Set 4 | kapaa
# Processing Record 25 of Set 4 | bathsheba
# Processing Record 26 of Set 4 | kokopo
# Processing Record 27 of Set 4 | mouzakion
# City not found. Skipping...
# Processing Record 28 of Set 4 | yerbogachen
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | mutoko
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | hami
# Processing Record 35 of Set 4 | ayagoz
# Processing Record 36 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 37 of Set 4 | port-cartier
# Processing Record 38 of Set 4 | butaritari
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | san cristobal
# Processing Record 41 of Set 4 | soderhamn
# Processing Record 42 of Set 4 | yenagoa
# Processing Record 43 of Set 4 | karatau
# Processing Record 44 of Set 4 | cabo san lucas
# Processing Record 45 of Set 4 | srednekolymsk
# Processing Record 46 of Set 4 | pontianak
# Processing Record 47 of Set 4 | vostok
# Processing Record 48 of Set 4 | sibolga
# Processing Record 49 of Set 4 | lincoln
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | dukat
# Processing Record 2 of Set 5 | alta floresta
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | patzun
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | benguela
# Processing Record 7 of Set 5 | bayan
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | deputatskiy
# Processing Record 10 of Set 5 | kampene
# City not found. Skipping...
# Processing Record 11 of Set 5 | fairbanks
# Processing Record 12 of Set 5 | aruppukkottai
# Processing Record 13 of Set 5 | aravete
# Processing Record 14 of Set 5 | bambanglipuro
# Processing Record 15 of Set 5 | ranfurly
# Processing Record 16 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 5 | gerpinnes
# Processing Record 18 of Set 5 | nouadhibou
# Processing Record 19 of Set 5 | dubenskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | dongsheng
# Processing Record 21 of Set 5 | drummondville
# Processing Record 22 of Set 5 | thompson
# Processing Record 23 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 5 | manoel urbano
# Processing Record 25 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 5 | sao gabriel da cachoeira
# Processing Record 28 of Set 5 | korla
# Processing Record 29 of Set 5 | vanimo
# Processing Record 30 of Set 5 | oranjemund
# Processing Record 31 of Set 5 | san rafael
# Processing Record 32 of Set 5 | saint-pierre
# Processing Record 33 of Set 5 | mar del plata
# Processing Record 34 of Set 5 | kiama
# Processing Record 35 of Set 5 | rio gallegos
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | angoche
# Processing Record 38 of Set 5 | kangaatsiaq
# Processing Record 39 of Set 5 | tawang
# Processing Record 40 of Set 5 | burhanpur
# Processing Record 41 of Set 5 | antofagasta
# Processing Record 42 of Set 5 | muros
# Processing Record 43 of Set 5 | constitucion
# Processing Record 44 of Set 5 | isiro
# Processing Record 45 of Set 5 | christchurch
# Processing Record 46 of Set 5 | gamba
# Processing Record 47 of Set 5 | bulaevo
# Processing Record 48 of Set 5 | makinsk
# Processing Record 49 of Set 5 | griffith
# Processing Record 50 of Set 5 | isla vista
# Processing Record 1 of Set 6 | kamenka
# Processing Record 2 of Set 6 | marzuq
# Processing Record 3 of Set 6 | santiago del estero
# Processing Record 4 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 5 of Set 6 | nerang
# Processing Record 6 of Set 6 | ribeira grande
# Processing Record 7 of Set 6 | ishigaki
# Processing Record 8 of Set 6 | khatanga
# Processing Record 9 of Set 6 | isangel
# Processing Record 10 of Set 6 | nuuk
# Processing Record 11 of Set 6 | kaitangata
# Processing Record 12 of Set 6 | huarmey
# Processing Record 13 of Set 6 | mao
# Processing Record 14 of Set 6 | airai
# Processing Record 15 of Set 6 | imbituba
# Processing Record 16 of Set 6 | longyan
# Processing Record 17 of Set 6 | luderitz
# Processing Record 18 of Set 6 | durant
# Processing Record 19 of Set 6 | quanzhou
# Processing Record 20 of Set 6 | westport
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | shanghai
# Processing Record 23 of Set 6 | chicama
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | ponta do sol
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | pampierstad
# Processing Record 28 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 6 | rawson
# Processing Record 30 of Set 6 | chester
# Processing Record 31 of Set 6 | tuktoyaktuk
# Processing Record 32 of Set 6 | comines
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | klaksvik
# Processing Record 35 of Set 6 | port lincoln
# Processing Record 36 of Set 6 | portland
# Processing Record 37 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 38 of Set 6 | looc
# Processing Record 39 of Set 6 | hurghada
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | orlik
# Processing Record 42 of Set 6 | xacmaz
# Processing Record 43 of Set 6 | vila franca do campo
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | santa cruz
# Processing Record 46 of Set 6 | williston
# Processing Record 47 of Set 6 | axim
# Processing Record 48 of Set 6 | sumisip
# Processing Record 49 of Set 6 | shangqiu
# Processing Record 50 of Set 6 | egvekinot
# Processing Record 1 of Set 7 | kiunga
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | kariba
# Processing Record 4 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 7 | oktyabrskiy
# Processing Record 6 of Set 7 | atasu
# Processing Record 7 of Set 7 | sarangani
# Processing Record 8 of Set 7 | tumen
# Processing Record 9 of Set 7 | auki
# Processing Record 10 of Set 7 | coquimbo
# Processing Record 11 of Set 7 | alcudia
# Processing Record 12 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 7 | shagonar
# Processing Record 14 of Set 7 | mount gambier
# Processing Record 15 of Set 7 | nanakuli
# Processing Record 16 of Set 7 | karpogory
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | tombouctou
# Processing Record 19 of Set 7 | bubaque
# Processing Record 20 of Set 7 | baruun-urt
# Processing Record 21 of Set 7 | lebu
# Processing Record 22 of Set 7 | wattegama
# Processing Record 23 of Set 7 | peleduy
# Processing Record 24 of Set 7 | alugan
# Processing Record 25 of Set 7 | mezen
# Processing Record 26 of Set 7 | saint cloud
# Processing Record 27 of Set 7 | gairo
# Processing Record 28 of Set 7 | darhan
# Processing Record 29 of Set 7 | port alfred
# Processing Record 30 of Set 7 | vila
# Processing Record 31 of Set 7 | lerwick
# Processing Record 32 of Set 7 | pau dos ferros
# Processing Record 33 of Set 7 | aswan
# Processing Record 34 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 7 | coihaique
# Processing Record 36 of Set 7 | riyadh
# Processing Record 37 of Set 7 | kalia
# Processing Record 38 of Set 7 | tulnici
# Processing Record 39 of Set 7 | solnechnyy
# Processing Record 40 of Set 7 | araouane
# Processing Record 41 of Set 7 | udachnyy
# Processing Record 42 of Set 7 | yar-sale
# Processing Record 43 of Set 7 | kismayo
# Processing Record 44 of Set 7 | delta
# Processing Record 45 of Set 7 | myanaung
# Processing Record 46 of Set 7 | touros
# Processing Record 47 of Set 7 | hachinohe
# Processing Record 48 of Set 7 | angoram
# Processing Record 49 of Set 7 | santiago
# Processing Record 50 of Set 7 | yumen
# Processing Record 1 of Set 8 | bolobo
# Processing Record 2 of Set 8 | ruyigi
# Processing Record 3 of Set 8 | abha
# Processing Record 4 of Set 8 | shingu
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | rujewa
# Processing Record 7 of Set 8 | cukai
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | kijang
# Processing Record 10 of Set 8 | cascais
# Processing Record 11 of Set 8 | guantanamo
# Processing Record 12 of Set 8 | darnah
# Processing Record 13 of Set 8 | sorland
# Processing Record 14 of Set 8 | brufut
# Processing Record 15 of Set 8 | manjacaze
# Processing Record 16 of Set 8 | kuala terengganu
# Processing Record 17 of Set 8 | nanortalik
# Processing Record 18 of Set 8 | port hedland
# Processing Record 19 of Set 8 | teguldet
# Processing Record 20 of Set 8 | roosendaal
# Processing Record 21 of Set 8 | valledupar
# Processing Record 22 of Set 8 | marrakesh
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | bereda
# Processing Record 25 of Set 8 | zaysan
# Processing Record 26 of Set 8 | mangrol
# Processing Record 27 of Set 8 | eislingen
# Processing Record 28 of Set 8 | nueva helvecia
# Processing Record 29 of Set 8 | la roda
# Processing Record 30 of Set 8 | manggar
# Processing Record 31 of Set 8 | bonthe
# Processing Record 32 of Set 8 | santarem
# Processing Record 33 of Set 8 | budingen
# Processing Record 34 of Set 8 | la ronge
# Processing Record 35 of Set 8 | igarka
# Processing Record 36 of Set 8 | samarai
# Processing Record 37 of Set 8 | bintulu
# Processing Record 38 of Set 8 | oum hadjer
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | berbera
# Processing Record 41 of Set 8 | nizhnevartovsk
# Processing Record 42 of Set 8 | joshimath
# Processing Record 43 of Set 8 | sola
# Processing Record 44 of Set 8 | lagoa
# Processing Record 45 of Set 8 | lake charles
# Processing Record 46 of Set 8 | polis
# Processing Record 47 of Set 8 | paita
# Processing Record 48 of Set 8 | chenzhou
# Processing Record 49 of Set 8 | husavik
# Processing Record 50 of Set 8 | berlevag
# Processing Record 1 of Set 9 | santo antonio do ica
# Processing Record 2 of Set 9 | kuliyapitiya
# Processing Record 3 of Set 9 | ancud
# Processing Record 4 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 5 of Set 9 | umm lajj
# Processing Record 6 of Set 9 | acapulco
# Processing Record 7 of Set 9 | izhma
# Processing Record 8 of Set 9 | waingapu
# Processing Record 9 of Set 9 | the valley
# Processing Record 10 of Set 9 | redmond
# Processing Record 11 of Set 9 | neu-ulm
# Processing Record 12 of Set 9 | viedma
# Processing Record 13 of Set 9 | matamoros
# Processing Record 14 of Set 9 | tilichiki
# Processing Record 15 of Set 9 | umea
# Processing Record 16 of Set 9 | san ignacio
# Processing Record 17 of Set 9 | kisangani
# Processing Record 18 of Set 9 | pedasi
# Processing Record 19 of Set 9 | usak
# Processing Record 20 of Set 9 | majene
# Processing Record 21 of Set 9 | bud
# Processing Record 22 of Set 9 | nabire
# Processing Record 23 of Set 9 | san quintin
# Processing Record 24 of Set 9 | gamboma
# Processing Record 25 of Set 9 | kinablangan
# Processing Record 26 of Set 9 | vineland
# Processing Record 27 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 28 of Set 9 | maningrida
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | borovoy
# Processing Record 31 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 9 | vao
# Processing Record 33 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 9 | port moresby
# Processing Record 35 of Set 9 | tautira
# Processing Record 36 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 9 | banjar
# Processing Record 38 of Set 9 | san buenaventura
# Processing Record 39 of Set 9 | buala
# Processing Record 40 of Set 9 | bodaybo
# Processing Record 41 of Set 9 | sistranda
# Processing Record 42 of Set 9 | vestmannaeyjar
# Processing Record 43 of Set 9 | rio bueno
# Processing Record 44 of Set 9 | wanning
# Processing Record 45 of Set 9 | aklavik
# Processing Record 46 of Set 9 | antalaha
# Processing Record 47 of Set 9 | keffi
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | hervey bay
# Processing Record 50 of Set 9 | sabang
# Processing Record 1 of Set 10 | goderich
# Processing Record 2 of Set 10 | doha
# Processing Record 3 of Set 10 | leshan
# Processing Record 4 of Set 10 | pontian kecil
# Processing Record 5 of Set 10 | poum
# Processing Record 6 of Set 10 | rivadavia
# Processing Record 7 of Set 10 | kasongo-lunda
# Processing Record 8 of Set 10 | belaya gora
# Processing Record 9 of Set 10 | kaabong
# Processing Record 10 of Set 10 | krasnozerskoye
# Processing Record 11 of Set 10 | barra do garcas
# Processing Record 12 of Set 10 | namtsy
# Processing Record 13 of Set 10 | king city
# Processing Record 14 of Set 10 | helong
# Processing Record 15 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 10 | algarrobo
# Processing Record 17 of Set 10 | noumea
# Processing Record 18 of Set 10 | caceres
# Processing Record 19 of Set 10 | sofiyivka
# Processing Record 20 of Set 10 | price
# Processing Record 21 of Set 10 | lakhipur
# Processing Record 22 of Set 10 | pulsano
# Processing Record 23 of Set 10 | remanso
# Processing Record 24 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 10 | karratha
# Processing Record 26 of Set 10 | sitges
# Processing Record 27 of Set 10 | samoylovka
# Processing Record 28 of Set 10 | pembroke
# Processing Record 29 of Set 10 | joao pinheiro
# Processing Record 30 of Set 10 | buraydah
# Processing Record 31 of Set 10 | port macquarie
# Processing Record 32 of Set 10 | medina del campo
# Processing Record 33 of Set 10 | petatlan
# Processing Record 34 of Set 10 | erice
# Processing Record 35 of Set 10 | jalu
# Processing Record 36 of Set 10 | zhuhai
# Processing Record 37 of Set 10 | kosikha
# Processing Record 38 of Set 10 | rupert
# Processing Record 39 of Set 10 | kloulklubed
# Processing Record 40 of Set 10 | siwani
# City not found. Skipping...
# Processing Record 41 of Set 10 | ambulu
# Processing Record 42 of Set 10 | pleasant point
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | kolokani
# Processing Record 45 of Set 10 | laguna
# Processing Record 46 of Set 10 | longyearbyen
# Processing Record 47 of Set 10 | verkhoyansk
# Processing Record 48 of Set 10 | canton
# Processing Record 49 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 10 | okhotsk
# Processing Record 1 of Set 11 | toucheng
# Processing Record 2 of Set 11 | priargunsk
# Processing Record 3 of Set 11 | balikpapan
# Processing Record 4 of Set 11 | miyazu
# Processing Record 5 of Set 11 | outram
# Processing Record 6 of Set 11 | ostrovnoy
# Processing Record 7 of Set 11 | kanye
# Processing Record 8 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | khandyga
# Processing Record 10 of Set 11 | general pico
# Processing Record 11 of Set 11 | omagh
# Processing Record 12 of Set 11 | la baule-escoublac
# Processing Record 13 of Set 11 | saquarema
# Processing Record 14 of Set 11 | vardo
# Processing Record 15 of Set 11 | kyzyl-suu
# Processing Record 16 of Set 11 | mtambile
# Processing Record 17 of Set 11 | stornoway
# Processing Record 18 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 11 | atar
# Processing Record 20 of Set 11 | ishinomaki
# Processing Record 21 of Set 11 | mahanoro
# Processing Record 22 of Set 11 | mehamn
# Processing Record 23 of Set 11 | taicheng
# Processing Record 24 of Set 11 | lachi
# Processing Record 25 of Set 11 | dwarka
# Processing Record 26 of Set 11 | homer
# Processing Record 27 of Set 11 | shakawe
# Processing Record 28 of Set 11 | tessalit
# Processing Record 29 of Set 11 | nanzhou
# Processing Record 30 of Set 11 | ranong
# Processing Record 31 of Set 11 | jinxiang
# Processing Record 32 of Set 11 | eureka
# Processing Record 33 of Set 11 | hailey
# Processing Record 34 of Set 11 | kalmunai
# Processing Record 35 of Set 11 | koungou
# Processing Record 36 of Set 11 | aksu
# Processing Record 37 of Set 11 | yatou
# Processing Record 38 of Set 11 | sidrolandia
# Processing Record 39 of Set 11 | mapastepec
# Processing Record 40 of Set 11 | son la
# Processing Record 41 of Set 11 | broome
# Processing Record 42 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 11 | male
# Processing Record 44 of Set 11 | santa cruz de tenerife
# Processing Record 45 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 11 | kamina
# Processing Record 47 of Set 11 | ust-koksa
# Processing Record 48 of Set 11 | xinxiang
# Processing Record 49 of Set 11 | truro
# Processing Record 50 of Set 11 | kasangulu
# Processing Record 1 of Set 12 | ust-omchug
# Processing Record 2 of Set 12 | warren
# Processing Record 3 of Set 12 | jiangyou
# Processing Record 4 of Set 12 | ketchikan
# Processing Record 5 of Set 12 | havoysund
# Processing Record 6 of Set 12 | benghazi
# Processing Record 7 of Set 12 | gelemso
# Processing Record 8 of Set 12 | olafsvik
# Processing Record 9 of Set 12 | la union
# Processing Record 10 of Set 12 | empalme
# Processing Record 11 of Set 12 | tura
# Processing Record 12 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 12 | kruisfontein
# Processing Record 14 of Set 12 | ponta delgada
# Processing Record 15 of Set 12 | palauig
# Processing Record 16 of Set 12 | marawi
# Processing Record 17 of Set 12 | mareeba
# Processing Record 18 of Set 12 | mayor pablo lagerenza
# Processing Record 19 of Set 12 | necochea
# Processing Record 20 of Set 12 | soyo
# Processing Record 21 of Set 12 | lieksa
# Processing Record 22 of Set 12 | concordia
# Processing Record 23 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 12 | agua branca
# Processing Record 25 of Set 12 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 12 | amahai
# Processing Record 27 of Set 12 | guiglo
# Processing Record 28 of Set 12 | arcata
# Processing Record 29 of Set 12 | roscommon
# Processing Record 30 of Set 12 | tete
# Processing Record 31 of Set 12 | plettenberg bay
# Processing Record 32 of Set 12 | zyryanka
# Processing Record 33 of Set 12 | ternovskaya
# Processing Record 34 of Set 12 | phangnga
# Processing Record 35 of Set 12 | kadoma
# Processing Record 36 of Set 12 | bodden town
# Processing Record 37 of Set 12 | ongandjera
# Processing Record 38 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 12 | urumqi
# Processing Record 40 of Set 12 | presidencia roque saenz pena
# Processing Record 41 of Set 12 | malpe
# Processing Record 42 of Set 12 | manzhouli
# Processing Record 43 of Set 12 | kaihua
# Processing Record 44 of Set 12 | chum phae
# Processing Record 45 of Set 12 | bonavista
# Processing Record 46 of Set 12 | seljord
# Processing Record 47 of Set 12 | boden
# Processing Record 48 of Set 12 | umtata
# Processing Record 49 of Set 12 | veraval
# Processing Record 50 of Set 12 | hope mills
# Processing Record 1 of Set 13 | diamond bar
# Processing Record 2 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 13 | floro
# Processing Record 4 of Set 13 | colac
# Processing Record 5 of Set 13 | marquette
# Processing Record 6 of Set 13 | yinchuan
# Processing Record 7 of Set 13 | tiarei
# Processing Record 8 of Set 13 | rochefort
# Processing Record 9 of Set 13 | ypsonas
# Processing Record 10 of Set 13 | sonoita
# Processing Record 11 of Set 13 | el dorado
# Processing Record 12 of Set 13 | acarau
# Processing Record 13 of Set 13 | kenai
# Processing Record 14 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 13 | ada
# Processing Record 16 of Set 13 | northam
# Processing Record 17 of Set 13 | hohhot
# Processing Record 18 of Set 13 | catia la mar
# Processing Record 19 of Set 13 | trofarello
# Processing Record 20 of Set 13 | ixtapa
# Processing Record 21 of Set 13 | shieli
# Processing Record 22 of Set 13 | smoky lake
# Processing Record 23 of Set 13 | ust-ilimsk
# Processing Record 24 of Set 13 | port hardy
# Processing Record 25 of Set 13 | dryden
# Processing Record 26 of Set 13 | sao felix do xingu
# Processing Record 27 of Set 13 | tayshet
# Processing Record 28 of Set 13 | moba
# Processing Record 29 of Set 13 | tubinskiy
# Processing Record 30 of Set 13 | palmeira
# Processing Record 31 of Set 13 | moron
# Processing Record 32 of Set 13 | mercedes
# Processing Record 33 of Set 13 | namuac
# Processing Record 34 of Set 13 | kahului
# Processing Record 35 of Set 13 | dingle
# Processing Record 36 of Set 13 | kudymkar
# Processing Record 37 of Set 13 | tortoli
# Processing Record 38 of Set 13 | rodrigues alves
# Processing Record 39 of Set 13 | geraldton
# Processing Record 40 of Set 13 | marshfield
# Processing Record 41 of Set 13 | xining
# Processing Record 42 of Set 13 | ornskoldsvik
# Processing Record 43 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 13 | nacala
# Processing Record 45 of Set 13 | hay river
# Processing Record 46 of Set 13 | setermoen
# Processing Record 47 of Set 13 | vedi
# Processing Record 48 of Set 13 | luziania
# Processing Record 49 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 13 | vinh
# Processing Record 1 of Set 14 | moussoro
# Processing Record 2 of Set 14 | luganville
# Processing Record 3 of Set 14 | santa branca
# Processing Record 4 of Set 14 | mersing
# Processing Record 5 of Set 14 | saint-francois
# Processing Record 6 of Set 14 | saint-jean-de-maurienne
# Processing Record 7 of Set 14 | bay roberts
# Processing Record 8 of Set 14 | anadyr
# Processing Record 9 of Set 14 | grindavik
# Processing Record 10 of Set 14 | moree
# Processing Record 11 of Set 14 | kipushi
# Processing Record 12 of Set 14 | mount isa
# Processing Record 13 of Set 14 | kaifeng
# Processing Record 14 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 14 | abu dhabi
# Processing Record 16 of Set 14 | opuwo
# Processing Record 17 of Set 14 | talaya
# Processing Record 18 of Set 14 | malakal
# Processing Record 19 of Set 14 | santa marta de tormes
# Processing Record 20 of Set 14 | sitka
# Processing Record 21 of Set 14 | zhigansk
# Processing Record 22 of Set 14 | tabuk
# Processing Record 23 of Set 14 | celestun
# Processing Record 24 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 14 | pansemal
# Processing Record 26 of Set 14 | lata
# Processing Record 27 of Set 14 | sisimiut
# Processing Record 28 of Set 14 | tutoia
# Processing Record 29 of Set 14 | college
# Processing Record 30 of Set 14 | pasni
# Processing Record 31 of Set 14 | wajima
# Processing Record 32 of Set 14 | ous
# Processing Record 33 of Set 14 | maltahohe
# Processing Record 34 of Set 14 | marsaxlokk
# Processing Record 35 of Set 14 | oistins
# Processing Record 36 of Set 14 | saint anthony
# Processing Record 37 of Set 14 | cabot
# Processing Record 38 of Set 14 | czersk
# Processing Record 39 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 14 | pedro juan caballero
# Processing Record 41 of Set 14 | san borja
# Processing Record 42 of Set 14 | asau
# Processing Record 43 of Set 14 | ashqelon
# Processing Record 44 of Set 14 | omsukchan
# Processing Record 45 of Set 14 | roebourne
# Processing Record 46 of Set 14 | placer
# Processing Record 47 of Set 14 | fougamou
# Processing Record 48 of Set 14 | lokoja
# Processing Record 49 of Set 14 | baykit
# Processing Record 50 of Set 14 | mackay
# Processing Record 1 of Set 15 | turukhansk
# Processing Record 2 of Set 15 | sakaraha
# Processing Record 3 of Set 15 | puerto ayacucho
# Processing Record 4 of Set 15 | uray
# Processing Record 5 of Set 15 | hambantota
# Processing Record 6 of Set 15 | hobyo
# Processing Record 7 of Set 15 | haines junction
# Processing Record 8 of Set 15 | saint-denis
# Processing Record 9 of Set 15 | maceio
# Processing Record 10 of Set 15 | sur
# Processing Record 11 of Set 15 | gorey
# Processing Record 12 of Set 15 | nizwa
# Processing Record 13 of Set 15 | damghan
# Processing Record 14 of Set 15 | iratosu
# Processing Record 15 of Set 15 | taltal
# Processing Record 16 of Set 15 | san jeronimo
# Processing Record 17 of Set 15 | bajil
# Processing Record 18 of Set 15 | batagay-alyta
# Processing Record 19 of Set 15 | waddan
# Processing Record 20 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 15 | el alto
# Processing Record 22 of Set 15 | lae
# Processing Record 23 of Set 15 | mahajanga
# Processing Record 24 of Set 15 | saint-joseph
# Processing Record 25 of Set 15 | walvis bay
# Processing Record 26 of Set 15 | petropavlovka
# Processing Record 27 of Set 15 | kudahuvadhoo
# Processing Record 28 of Set 15 | skerries
# Processing Record 29 of Set 15 | copiapo
# Processing Record 30 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 15 | bumba
# Processing Record 32 of Set 15 | taizhou
# Processing Record 33 of Set 15 | grand gaube
# Processing Record 34 of Set 15 | ginir
# Processing Record 35 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 15 | tommot
# Processing Record 37 of Set 15 | kurunegala
# Processing Record 38 of Set 15 | kontagora
# Processing Record 39 of Set 15 | yorosso
# Processing Record 40 of Set 15 | hirara
# Processing Record 41 of Set 15 | alghero
# Processing Record 42 of Set 15 | comodoro rivadavia
# Processing Record 43 of Set 15 | palora
# Processing Record 44 of Set 15 | psebay
# Processing Record 45 of Set 15 | tygda
# Processing Record 46 of Set 15 | orcopampa
# Processing Record 47 of Set 15 | durban
# Processing Record 48 of Set 15 | novoagansk
# Processing Record 49 of Set 15 | lewisporte
# Processing Record 50 of Set 15 | tarbagatay
# Processing Record 1 of Set 16 | luanda
# Processing Record 2 of Set 16 | rabo de peixe
# Processing Record 3 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 16 | la asuncion
# Processing Record 5 of Set 16 | culaba
# Processing Record 6 of Set 16 | kindu
# Processing Record 7 of Set 16 | salamiyah
# Processing Record 8 of Set 16 | iberia
# Processing Record 9 of Set 16 | riviere-du-loup
# Processing Record 10 of Set 16 | galveston
# Processing Record 11 of Set 16 | orizaba
# Processing Record 12 of Set 16 | misratah
# Processing Record 13 of Set 16 | puerto escondido
# Processing Record 14 of Set 16 | gorodovikovsk
# Processing Record 15 of Set 16 | show low
# Processing Record 16 of Set 16 | avera
# Processing Record 17 of Set 16 | thio
# Processing Record 18 of Set 16 | karpathos
# Processing Record 19 of Set 16 | alamogordo
# Processing Record 20 of Set 16 | mecca
# Processing Record 21 of Set 16 | gurlan
# Processing Record 22 of Set 16 | whitianga
# Processing Record 23 of Set 16 | saint-louis
# Processing Record 24 of Set 16 | kashi
# Processing Record 25 of Set 16 | tual
# Processing Record 26 of Set 16 | monte azul
# Processing Record 27 of Set 16 | arkhangelsk
# Processing Record 28 of Set 16 | burnie
# Processing Record 29 of Set 16 | nampula
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 721

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     74.88        60           0
# 1         Tuy Hoa      VN  13.0833  109.3000     71.78        88         100
# 2       Pemangkat      ID   1.1667  108.9667     78.17        87         100
# 3      Skibbereen      IE  51.5500   -9.2667     52.11        84         100
# 4     Grahamstown      ZA -33.3042   26.5328     62.47        89         100
# 5        Flinders      AU -34.5833  150.8552     68.38        81          99
# 6         Qaanaaq      GL  77.4840  -69.3632      2.34        83         100
# 7  Severo-Kurilsk      RU  50.6789  156.1250     28.36        94         100
# 8       Busselton      AU -33.6500  115.3333     65.05        83           0
# 9          Castro      BR -24.7911  -50.0119     75.16        81          36
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1       12.41     overcast clouds
# 2        7.76     overcast clouds
# 3       31.14     overcast clouds
# 4       20.87     overcast clouds
# 5        5.99       moderate rain
# 6        4.25     overcast clouds
# 7        5.46          light snow
# 8        7.56           clear sky
# 9        8.75    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
